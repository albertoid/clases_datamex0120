# %% [markdown]
# # Probs dado

# %%
def par(x):
    return (x%2==0)

# %%
sample_space=[1,2,3,4,5,6]

caras=len(sample_space)

pares=len([e for e in sample_space if par(e)])

pares_prob=pares/caras

pares_prob
# Out:
# 0.5

# %% [markdown]
# # Distribuciones discretas

# %%
# binomial

from scipy.stats import binom
import matplotlib.pyplot as plt

# binom.pmf(k, n, p)

binom.pmf(5, 10, 0.3)
# Out:
# 0.10291934520000007

# %%
binom.pmf(5, 10, 0.5)
# Out:
# 0.24609375000000025

# %%
binom.cdf(5, 10, 0.5)
# Out:
# 0.6230468749999999

# %%
x=[i for i in range(6)]
y=[binom.pmf (x, 10, 0.5) for x in x]
plt.plot(x, y);
sum(y)
# Out:
# 0.6230468750000006

# %%
x=[i for i in range(10)]
y=[binom.cdf (x, 10, 0.5) for x in x]
plt.plot(x, y);

# %%
n=10
p=0.3

media, var, sime, kurt=binom.stats(n, p, moments='mvsk')
kurt
# Out:
# array(-0.12380952)

# %%
# binomial negativa

from scipy.stats import nbinom

nbinom.pmf(5, 10, 0.5)
# Out:
# 0.061096191406250215

# %%
nbinom.cdf(5, 10, 0.5)
# Out:
# 0.15087890625000008

# %%
x=[i for i in range(100)]
y=[nbinom.pmf (x, 10, 0.5) for x in x]
plt.plot(x, y);

# %%
x=[i for i in range(20)]
y=[nbinom.cdf (x, 10, 0.5) for x in x]
plt.plot(x, y);

# %%
# geometrica

# geom.pmf(k, p)

from scipy.stats import geom

geom.pmf(1, 0.7)
# Out:
# 0.7

# %%
geom.cdf(5, 0.7)
# Out:
# 0.99757

# %%
x=[i for i in range(10)]
y=[geom.pmf (x, 0.7) for x in x]
plt.plot(x, y);

# %%
x=[i for i in range(10)]
y=[geom. cdf (x, 0.7) for x in x]
plt.plot(x, y);

# %%
# uniforme discreta

# radint.pmf(k, a, b)

from scipy.stats import randint

randint.pmf([0, 6,7,8], 0, 8)
# Out:
# array([0.125, 0.125, 0.125, 0.   ])

# %%
x=[i for i in range(10)]
y=[randint.pmf (x, 0, 8) for x in x]
plt.plot(x, y);

# %%
x=[i for i in range(10)]
y=[randint.cdf (x, 0, 8) for x in x]
plt.plot(x, y);

# %%
# poisson

from scipy.stats import poisson

# poisson.pmf(x, lambda)

poisson.pmf(2, 3.5)
# Out:
# 0.18495897346170082

# %%
poisson.cdf(2, 3.5)
# Out:
# 0.32084719886213414

# %%
x=[i for i in range(15)]
y=[poisson.pmf (x,3.5) for x in x]
plt.plot(x, y);

# %%
x=[i for i in range(15)]
y=[poisson.cdf (x,3.5) for x in x]
plt.plot(x, y);

# %% [markdown]
# # Distribuciones continuas

# %%
# uniforme

from scipy.stats import uniform

uniform.pdf(0.4)
# Out:
# 1.0

# %%
uniform.cdf(0.6)
# Out:
# 0.6

# %%
# normal

from scipy.stats import norm

# norm.pdf(x, mu, sigma)

norm.pdf(3, 4, 1)
# Out:
# 0.24197072451914337

# %%
norm.cdf(3, 4, 1)
# Out:
# 0.15865525393145707

# %%
x=[i for i in range(15)]
y=[norm.pdf (x, 4, 1) for x in x]
plt.plot(x, y);

# %%
x=[i for i in range(15)]
y=[norm.cdf (x, 4, 1) for x in x]
plt.plot(x, y);

# %%
# t-Student

from scipy.stats import t

# t.pdf(x, dof)

t.pdf(3, 9)
# Out:
# 0.012126090902239645

# %%
t.cdf(3, 9)
# Out:
# 0.9925218180447929

# %%
x=[i for i in range(15)]
y=[t.pdf (x, 9) for x in x]
plt.plot(x, y);

# %%
x=[i for i in range(15)]
y=[t.cdf (x, 9) for x in x]
plt.plot(x, y);
