# %% [markdown]
# # Scripting, Code Pipeline

# %%
import funciones

# %%
funciones.suma(2,2)
# Out:
# 4

# %%
funciones.resta(2,2)
# Out:
# 0

# %%
funciones.mult(2,6)
# Out:
# 12

# %%
from funciones import *

# %%
suma(2,5)
# Out:
# 7

# %%
from funciones import resta

# %%
resta(3,2)
# Out:
# 1

# %%
import import_ipynb
from func import *

# %%
algo(2,5,6)
# Out:
# -0.16666666666666696

# %% [markdown]
# # PDF-MAIL

# %%
# FPDF

#!pip3 install fpdf

# %%
from fpdf import FPDF

# %%
# 1-hola mundo
