# %%
import numpy as np
import pandas as pd

# %%
animals=pd.read_csv('data/animals.csv')
animals.head()
# Out:
#    brainwt   bodywt      animal
# 0    3.385   44.500  Arctic_fox
# 1    0.480   15.499  Owl_monkey
# 2    1.350    8.100      Beaver
# 3  464.983  423.012         Cow
# 4   36.328  119.498   Gray_wolf

# %%
animals['bodywtkg']=animals.bodywt*0.4536
animals.head()
# Out:
#    brainwt   bodywt      animal    bodywtkg
# 0    3.385   44.500  Arctic_fox   20.185200
# 1    0.480   15.499  Owl_monkey    7.030346
# 2    1.350    8.100      Beaver    3.674160
# 3  464.983  423.012         Cow  191.878243
# 4   36.328  119.498   Gray_wolf   54.204293

# %%
animals['wtratio']=animals.bodywt/animals.brainwt
animals.head()
# Out:
#    brainwt   bodywt      animal    bodywtkg    wtratio
# 0    3.385   44.500  Arctic_fox   20.185200  13.146233
# 1    0.480   15.499  Owl_monkey    7.030346  32.289583
# 2    1.350    8.100      Beaver    3.674160   6.000000
# 3  464.983  423.012         Cow  191.878243   0.909736
# 4   36.328  119.498   Gray_wolf   54.204293   3.289419

# %%
animals['zerocheck']=np.where(animals.brainwt!=0,
                              animals.bodywt/animals.brainwt, 0)
animals.head()
# Out:
#    brainwt   bodywt      animal    bodywtkg    wtratio  zerocheck
# 0    3.385   44.500  Arctic_fox   20.185200  13.146233  13.146233
# 1    0.480   15.499  Owl_monkey    7.030346  32.289583  32.289583
# 2    1.350    8.100      Beaver    3.674160   6.000000   6.000000
# 3  464.983  423.012         Cow  191.878243   0.909736   0.909736
# 4   36.328  119.498   Gray_wolf   54.204293   3.289419   3.289419

# %%
# eval y query

df1=pd.DataFrame(np.random.random((10, 3)), columns=['a', 'b', 'c'])
df2=pd.DataFrame(np.random.random((10, 3)), columns=['a', 'b', 'c'])
display(df1)
display(df2)
# Out:
#           a         b         c
# 0  0.168597  0.431360  0.290233
# 1  0.193634  0.832200  0.774726
# 2  0.496264  0.545177  0.780766
# 3  0.809057  0.045967  0.209158
# 4  0.402477  0.087957  0.507479
# 5  0.322953  0.369083  0.268515
# 6  0.069703  0.225016  0.170827
# 7  0.605040  0.264278  0.407568
# 8  0.183557  0.321808  0.432014
# 9  0.473009  0.946458  0.432249
#           a         b         c
# 0  0.127581  0.221229  0.764212
# 1  0.420334  0.009576  0.228139
# 2  0.370844  0.860917  0.110651
# 3  0.751425  0.189824  0.993280
# 4  0.416917  0.601052  0.828216
# 5  0.534756  0.266610  0.752159
# 6  0.864272  0.072034  0.860971
# 7  0.322954  0.374255  0.335288
# 8  0.799717  0.328765  0.452518
# 9  0.040874  0.386522  0.649934

# %%
pd.eval('df1<df2')
# Out:
#        a      b      c
# 0  False  False   True
# 1   True  False  False
# 2  False   True  False
# 3  False   True   True
# 4   True   True   True
# 5   True  False   True
# 6   True  False   True
# 7  False   True  False
# 8   True   True   True
# 9  False  False   True

# %%
df1.eval('b>0')
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# dtype: bool

# %%
df1.query('b>0.2')
# Out:
#           a         b         c
# 0  0.168597  0.431360  0.290233
# 1  0.193634  0.832200  0.774726
# 2  0.496264  0.545177  0.780766
# 5  0.322953  0.369083  0.268515
# 6  0.069703  0.225016  0.170827
# 7  0.605040  0.264278  0.407568
# 8  0.183557  0.321808  0.432014
# 9  0.473009  0.946458  0.432249

# %%
df1.query('b<0')
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
# lookup

seasons=pd.DataFrame(np.random.random((10, 4)), 
                     columns=['winter', 'spring', 'summer', 'autumn'])
seasons
# Out:
#      winter    spring    summer    autumn
# 0  0.693158  0.118939  0.358985  0.653661
# 1  0.078766  0.835782  0.594461  0.289062
# 2  0.742512  0.130116  0.268622  0.856866
# 3  0.414958  0.758280  0.718728  0.280024
# 4  0.416505  0.255432  0.890818  0.633970
# 5  0.941654  0.788924  0.807855  0.733182
# 6  0.489668  0.105292  0.460665  0.603083
# 7  0.038451  0.081407  0.358735  0.136628
# 8  0.174141  0.572029  0.928376  0.106260
# 9  0.865193  0.566879  0.847461  0.321597

# %%
look=['summer', 'winter', 'spring', 
      'winter', 'summer', 'autumn',
      'summer','summer', 'winter', 'spring']

seasons.lookup(seasons.index, look)
# Out:
# array([0.35898502, 0.07876601, 0.13011559, 0.41495755, 0.89081755,
#        0.73318174, 0.46066514, 0.35873509, 0.17414081, 0.5668785 ])

# %%
# get

seasons.get(seasons.winter>0.5)
# Out:
#      winter    spring    summer    autumn
# 0  0.693158  0.118939  0.358985  0.653661
# 2  0.742512  0.130116  0.268622  0.856866
# 5  0.941654  0.788924  0.807855  0.733182
# 9  0.865193  0.566879  0.847461  0.321597

# %%
seasons.get('winter')
# Out:
# 0    0.693158
# 1    0.078766
# 2    0.742512
# 3    0.414958
# 4    0.416505
# 5    0.941654
# 6    0.489668
# 7    0.038451
# 8    0.174141
# 9    0.865193
# Name: winter, dtype: float64

# %%
seasons.winter
# Out:
# 0    0.693158
# 1    0.078766
# 2    0.742512
# 3    0.414958
# 4    0.416505
# 5    0.941654
# 6    0.489668
# 7    0.038451
# 8    0.174141
# 9    0.865193
# Name: winter, dtype: float64

# %%
# index y reindex

url='https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

cols=['mpg', 'cylinders', 'displacement', 'horsepower', 
      'weight', 'acceleration', 'model_year', 'origin', 'car_name']

# %%
auto=pd.read_csv(url, sep='\\s+', names=cols)
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
auto.index=pd.RangeIndex(0, 398*2, 2)
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 2  15.0          8         350.0      165.0  3693.0          11.5          70
# 4  18.0          8         318.0      150.0  3436.0          11.0          70
# 6  16.0          8         304.0      150.0  3433.0          12.0          70
# 8  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 2       1          buick skylark 320
# 4       1         plymouth satellite
# 6       1              amc rebel sst
# 8       1                ford torino

# %%
auto.index=range(len(auto))
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.index=auto.car_name
auto.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car_name
# chevrolet chevelle malibu  18.0          8         307.0      130.0  3504.0
# buick skylark 320          15.0          8         350.0      165.0  3693.0
# plymouth satellite         18.0          8         318.0      150.0  3436.0
# amc rebel sst              16.0          8         304.0      150.0  3433.0
# ford torino                17.0          8         302.0      140.0  3449.0
#
#                            acceleration  model_year  origin  \
# car_name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1
#
#                                             car_name
# car_name
# chevrolet chevelle malibu  chevrolet chevelle malibu
# ...

# %%
auto.set_index('mpg', inplace=True)
auto.head()
# Out:
#       cylinders  displacement horsepower  weight  acceleration  model_year  \
# mpg
# 18.0          8         307.0      130.0  3504.0          12.0          70
# 15.0          8         350.0      165.0  3693.0          11.5          70
# 18.0          8         318.0      150.0  3436.0          11.0          70
# 16.0          8         304.0      150.0  3433.0          12.0          70
# 17.0          8         302.0      140.0  3449.0          10.5          70
#
#       origin                   car_name
# mpg
# 18.0       1  chevrolet chevelle malibu
# 15.0       1          buick skylark 320
# 18.0       1         plymouth satellite
# 16.0       1              amc rebel sst
# 17.0       1                ford torino

# %%
auto.describe()#.loc['mean']
# Out:
#         cylinders  displacement       weight  acceleration  model_year  \
# count  398.000000    398.000000   398.000000    398.000000  398.000000
# mean     5.454774    193.425879  2970.424623     15.568090   76.010050
# std      1.701004    104.269838   846.841774      2.757689    3.697627
# min      3.000000     68.000000  1613.000000      8.000000   70.000000
# 25%      4.000000    104.250000  2223.750000     13.825000   73.000000
# 50%      4.000000    148.500000  2803.500000     15.500000   76.000000
# 75%      8.000000    262.000000  3608.000000     17.175000   79.000000
# max      8.000000    455.000000  5140.000000     24.800000   82.000000
#
#            origin
# count  398.000000
# mean     1.572864
# std      0.802055
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
# multiindex

(auto.car_name+' '+auto.model_year.map(str)).value_counts()
# Out:
# ford pinto 75                   2
# plymouth reliant 81             2
# mazda rx2 coupe 72              1
# chrysler lebaron salon 81       1
# ford escort 2h 81               1
#                                ..
# chevrolet caprice classic 73    1
# pontiac sunbird coupe 77        1
# amc concord 78                  1
# volkswagen jetta 81             1
# datsun 310 80                   1
# Length: 396, dtype: int64

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 398 entries, 18.0 to 31.0
# Data columns (total 8 columns):
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null object
# weight          398 non-null float64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null int64
# car_name        398 non-null object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 38.0+ KB

# %%
type(str(auto.model_year))
# Out:
# str

# %%
type(auto.model_year.map(str))
# Out:
# pandas.core.series.Series

# %%
type(auto.model_year.apply(lambda x: str(x)))
# Out:
# pandas.core.series.Series

# %%
auto.drop_duplicates(subset=['car_name', 'model_year'], inplace=True)

# %%
auto.set_index(['car_name', 'model_year'], inplace=True)
auto.head()
# Out:
#                                       cylinders  displacement horsepower  \
# car_name                  model_year
# chevrolet chevelle malibu 70                  8         307.0      130.0
# buick skylark 320         70                  8         350.0      165.0
# plymouth satellite        70                  8         318.0      150.0
# amc rebel sst             70                  8         304.0      150.0
# ford torino               70                  8         302.0      140.0
#
#                                       weight  acceleration  origin
# car_name                  model_year
# chevrolet chevelle malibu 70          3504.0          12.0       1
# buick skylark 320         70          3693.0          11.5       1
# plymouth satellite        70          3436.0          11.0       1
# amc rebel sst             70          3433.0          12.0       1
# ford torino               70          3449.0          10.5       1

# %%
auto.index[0]
# Out:
# ('chevrolet chevelle malibu', 70)

# %%
# reindex

new_index=[('fiat punto', 71)]+list(auto.index)

auto_reindexed=auto.reindex(new_index)
auto_reindexed.head()
# Out:
#                                       cylinders  displacement horsepower  \
# car_name                  model_year
# fiat punto                71                NaN           NaN        NaN
# chevrolet chevelle malibu 70                8.0         307.0      130.0
# buick skylark 320         70                8.0         350.0      165.0
# plymouth satellite        70                8.0         318.0      150.0
# amc rebel sst             70                8.0         304.0      150.0
#
#                                       weight  acceleration  origin
# car_name                  model_year
# fiat punto                71             NaN           NaN     NaN
# chevrolet chevelle malibu 70          3504.0          12.0     1.0
# buick skylark 320         70          3693.0          11.5     1.0
# plymouth satellite        70          3436.0          11.0     1.0
# amc rebel sst             70          3433.0          12.0     1.0

# %%
# encadenando metodos

ks=pd.read_csv('data/ks-projects-201801.csv')
ks.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
ks.isnull().sum()
# Out:
# ID                     0
# name                   4
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3797
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64

# %%
ks.isna().sum()
# Out:
# ID                     0
# name                   4
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3797
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64

# %%
ks.country.value_counts()
# Out:
# US      292627
# GB       33672
# CA       14756
# AU        7839
# DE        4171
# N,0"      3797
# FR        2939
# IT        2878
# NL        2868
# ES        2276
# SE        1757
# MX        1752
# NZ        1447
# DK        1113
# IE         811
# CH         761
# NO         708
# HK         618
# BE         617
# AT         597
# SG         555
# LU          62
# JP          40
# Name: country, dtype: int64

# %%
ks.drop(columns=['usd pledged']).replace('N,0"', 'Unknown').head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd_pledged_real  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB               0.0
# ...

# %%
# assign

ks.assign(dollar_per_backer=ks.usd_pledged_real/ks.backers, 
          duration=pd.to_datetime(ks.deadline)-pd.to_datetime(ks.launched)).head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
# correlacion

vehicles=pd.read_csv('data/vehicles/vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
vehicles['City MPG'].corr(vehicles['Highway MPG'])
# Out:
# 0.92385558852884

# %%
vehicles.corr()
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.037876   0.082469
# Engine Displacement      0.037876             1.000000   0.901858
# Cylinders                0.082469             0.901858   1.000000
# Fuel Barrels/Year       -0.221084             0.789752   0.739517
# City MPG                 0.161818            -0.740317  -0.703866
# Highway MPG              0.267259            -0.715039  -0.650287
# Combined MPG             0.204751            -0.746782  -0.698648
# CO2 Emission Grams/Mile -0.222300             0.803520   0.752393
# Fuel Cost/Year          -0.091913             0.769678   0.778153
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.221084  0.161818     0.267259
# Engine Displacement               0.789752 -0.740317    -0.715039
# Cylinders                         0.739517 -0.703866    -0.650287
# ...

# %%
vehicles.corr(method='pearson')  # [-1, 1]
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.037876   0.082469
# Engine Displacement      0.037876             1.000000   0.901858
# Cylinders                0.082469             0.901858   1.000000
# Fuel Barrels/Year       -0.221084             0.789752   0.739517
# City MPG                 0.161818            -0.740317  -0.703866
# Highway MPG              0.267259            -0.715039  -0.650287
# Combined MPG             0.204751            -0.746782  -0.698648
# CO2 Emission Grams/Mile -0.222300             0.803520   0.752393
# Fuel Cost/Year          -0.091913             0.769678   0.778153
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.221084  0.161818     0.267259
# Engine Displacement               0.789752 -0.740317    -0.715039
# Cylinders                         0.739517 -0.703866    -0.650287
# ...

# %%
vehicles.corr(method='spearman') # [-1, 1]
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.051370   0.068727
# Engine Displacement      0.051370             1.000000   0.927979
# Cylinders                0.068727             0.927979   1.000000
# Fuel Barrels/Year       -0.214857             0.827152   0.784595
# City MPG                 0.157137            -0.848167  -0.818672
# Highway MPG              0.266934            -0.754080  -0.698356
# Combined MPG             0.205080            -0.824065  -0.783362
# CO2 Emission Grams/Mile -0.215108             0.831333   0.788777
# Fuel Cost/Year          -0.091437             0.794755   0.790481
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.214857  0.157137     0.266934
# Engine Displacement               0.827152 -0.848167    -0.754080
# Cylinders                         0.784595 -0.818672    -0.698356
# ...

# %%
vehicles.corr(method='kendall') # [-1, 1] pero en realidad [0,1]
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.037129   0.053817
# Engine Displacement      0.037129             1.000000   0.814208
# Cylinders                0.053817             0.814208   1.000000
# Fuel Barrels/Year       -0.152204             0.663295   0.664196
# City MPG                 0.110961            -0.692362  -0.702624
# Highway MPG              0.189554            -0.579679  -0.575368
# Combined MPG             0.145378            -0.658312  -0.662099
# CO2 Emission Grams/Mile -0.151399             0.661452   0.662733
# Fuel Cost/Year          -0.064127             0.623155   0.668536
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.152204  0.110961     0.189554
# Engine Displacement               0.663295 -0.692362    -0.579679
# Cylinders                         0.664196 -0.702624    -0.575368
# ...

# %%
# Ejemplo Data Analysis

student=pd.read_csv('data/student-mat.csv')
student.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
student.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
student.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
pd.crosstab(index=student.sex, columns='count')
# Out:
# col_0  count
# sex
# F        208
# M        187

# %%
pd.crosstab(index=student.sex, columns=student.activities)
# Out:
# activities   no  yes
# sex
# F           112   96
# M            82  105

# %%
pd.crosstab(index=student.address, columns=student.famsize)
# Out:
# famsize  GT3  LE3
# address
# R         68   20
# U        213   94

# %%
# pivot 

student.pivot_table(index=['school'], columns=['sex', 'studytime'],
                    values=['G3'], fill_value=0)
# Out:
#                   G3                                                  \
# sex                F                                    M
# studytime          1          2          3   4          1          2
# school
# GP         10.652174   9.363636  10.590909  11  10.363636  11.090909
# MS          5.250000  10.428571  11.571429   0   8.750000  10.875000
#
#
# sex
# studytime          3     4
# school
# GP         13.923077  11.7
# MS         13.000000   0.0

# %%
student.G3
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
student.pivot_table(index=['school'], columns=['sex', 'studytime'],
                    values=['G3'], fill_value=0, aggfunc='count')
# Out:
#            G3
# sex         F               M
# studytime   1   2   3   4   1   2   3   4
# school
# GP         23  99  44  17  66  77  13  10
# MS          4  14   7   0  12   8   1   0

# %%
student.pivot_table(index=['school'], columns=['sex', 'studytime'],
                    values=['G3'], fill_value=0, aggfunc='mean')
# Out:
#                   G3                                                  \
# sex                F                                    M
# studytime          1          2          3   4          1          2
# school
# GP         10.652174   9.363636  10.590909  11  10.363636  11.090909
# MS          5.250000  10.428571  11.571429   0   8.750000  10.875000
#
#
# sex
# studytime          3     4
# school
# GP         13.923077  11.7
# MS         13.000000   0.0

# %%
print (student.pivot_table(index=['school'], columns=['sex', 'studytime'],
                    values=['G3'], fill_value=0, aggfunc='max'))
# Out:
#            G3
# sex         F               M
# studytime   1   2   3   4   1   2   3   4
# school
# GP         18  18  19  18  19  19  18  20
# MS         10  15  19   0  16  14  13   0

# %%
student.G3.unique()
# Out:
# array([ 6, 10, 15, 11, 19,  9, 12, 14, 16,  5,  8, 17, 18, 13, 20,  7,  0,
#         4])
